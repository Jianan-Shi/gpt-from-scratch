# %% [markdown]
# # Bigram 闭卷复现
#
# **规则：不看视频、不看 `01_bigram.ipynb`。写不出来的地方 = 真实盲区。**

# %% [markdown]
# ## 1. 读数据、建 stoi / itos

# %% [markdown]
# ## 2. 计数矩阵 → 归一化 → 采样 5 个名字

# %% [markdown]
# ## 3. 算 loss

# %% [markdown]
# ## 4. 神经网络版：one-hot → W → softmax → 交叉熵 → 梯度下降

# %% [markdown]
# ## 盲区记录
#
# 卡住的地方写在这里（这一步的真正产出）：
#
# -
